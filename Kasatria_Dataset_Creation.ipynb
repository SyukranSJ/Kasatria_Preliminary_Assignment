# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("dataset_interview.png")

display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=943x427>

# %%
# !apt-get update -qq
# !apt-get install -y tesseract-ocr -qq
# !pip install -q pytesseract
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# Upscale the image
scale = 3

upscaled = image.resize(
    (image.width * scale, image.height * scale),
    Image.Resampling.LANCZOS
)

display(upscaled)
# Out:
# <PIL.Image.Image image mode=RGBA size=2829x1281>

# %%
import pandas as pd

data = [
    ["Ali",22,"M",15000,"Highschool","Samsung Galaxy S3","x","x","x","x","","",""],
    ["Mutu",25,"M",30000,"Diploma","HTC One Note","x","x","x","","","",""],
    ["Lim",33,"M",36000,"Diploma","iPhone 5","x","x","x","","x","",""],
    ["Angie",47,"F",45000,"Diploma","iPhone 6s","x","","","x","x","x","x"],
    ["Jack",26,"M",25000,"Degree","Xiaomi MI3","x","x","x","","","",""],
    ["Mambutu",35,"M",18000,"Primary","Hua Wei Honour 6","x","x","x","x","x","x",""],
    ["Pierre",54,"M",120000,"Degree","Nokia E63","x","","","","","x","x"],
    ["Valerie",32,"F",80000,"Masters","iPhone 3Gs","x","x","x","","x","",""],
    ["Farah",19,"F",12000,"Primary","HTC Mozart 7","","","x","x","","x",""],
    ["Muhammad",22,"M",16000,"Primary","HTC One E8","x","x","x","","","",""],
    ["Regina",22,"F",15000,"Highschool","iPhone 6+","x","x","x","","x","",""],
    ["Trevor",25,"M",30000,"Diploma","OnePlus 2","x","","x","","","",""],
    ["Melinda",39,"F",33000,"Diploma","Samsung Galaxy A8","x","","","","","",""],
    ["Aishah",45,"F",42000,"Diploma","Lenovo VIBE Shot","x","","","","","",""],
    ["Abdullah",26,"M",25000,"Degree","iPhone 5s","x","x","x","","x","",""],
    ["Rizal",35,"M",18000,"Primary","Xiaomi MI3","x","x","x","","","",""],
    ["Wong",51,"M",110000,"Degree","iPhone 6s+","x","","","","x","x","x"],
    ["Jill",29,"F",75000,"Masters","iPhone 6s","x","x","","","x","",""],
    ["Polly",21,"F",12200,"Primary","Xiaomi Pad Tablet","x","x","x","x","","",""],
    ["Wanda",23,"F",17000,"Primary","Xiaomi MI4","x","x","x","","","",""]
]

columns = [
    "Name", "Age", "Gender", "Annual Income", "Education",
    "Phone Owned", "Email", "Web", "Mobile", "Walk-in",
    "Video Call", "Phone Call", "Letter"
]

df = pd.DataFrame(data, columns=columns)

display(df)
# Out:
#         Name  Age Gender  Annual Income   Education        Phone Owned Email  \
# 0        Ali   22      M          15000  Highschool  Samsung Galaxy S3     x
# 1       Mutu   25      M          30000     Diploma       HTC One Note     x
# 2        Lim   33      M          36000     Diploma           iPhone 5     x
# 3      Angie   47      F          45000     Diploma          iPhone 6s     x
# 4       Jack   26      M          25000      Degree         Xiaomi MI3     x
# 5    Mambutu   35      M          18000     Primary   Hua Wei Honour 6     x
# 6     Pierre   54      M         120000      Degree          Nokia E63     x
# 7    Valerie   32      F          80000     Masters         iPhone 3Gs     x
# 8      Farah   19      F          12000     Primary       HTC Mozart 7
# 9   Muhammad   22      M          16000     Primary         HTC One E8     x
# 10    Regina   22      F          15000  Highschool          iPhone 6+     x
# ...

# %%
print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nMissing values:")
print(df.isna().sum())

print("\nDuplicate rows:", df.duplicated().sum())

print("\nData types:")
print(df.dtypes)
# Out:
# Rows: 20
# Columns: 13
#
# Missing values:
# Name             0
# Age              0
# Gender           0
# Annual Income    0
# Education        0
# Phone Owned      0
# Email            0
# Web              0
# Mobile           0
# Walk-in          0
# Video Call       0
# Phone Call       0
# Letter           0
# dtype: int64
#
# Duplicate rows: 0
#
# Data types:
# Name             object
# Age               int64
# Gender           object
# Annual Income     int64
# Education        object
# Phone Owned      object
# Email            object
# Web              object
# Mobile           object
# Walk-in          object
# Video Call       object
# Phone Call       object
# Letter           object
# dtype: object

# %%
df.to_csv("kasatria_dataset.csv", index=False)

print("Dataset saved successfully.")

# %%
from google.colab import files

files.download("kasatria_dataset.csv")

# %%
print(df.shape)
# Out:
# (20, 13)

# %%
display(df)
# Out:
#         Name  Age Gender  Annual Income   Education        Phone Owned Email  \
# 0        Ali   22      M          15000  Highschool  Samsung Galaxy S3     x
# 1       Mutu   25      M          30000     Diploma       HTC One Note     x
# 2        Lim   33      M          36000     Diploma           iPhone 5     x
# 3      Angie   47      F          45000     Diploma          iPhone 6s     x
# 4       Jack   26      M          25000      Degree         Xiaomi MI3     x
# 5    Mambutu   35      M          18000     Primary   Hua Wei Honour 6     x
# 6     Pierre   54      M         120000      Degree          Nokia E63     x
# 7    Valerie   32      F          80000     Masters         iPhone 3Gs     x
# 8      Farah   19      F          12000     Primary       HTC Mozart 7
# 9   Muhammad   22      M          16000     Primary         HTC One E8     x
# 10    Regina   22      F          15000  Highschool          iPhone 6+     x
# ...

# %%
print(df.isnull().sum())
# Out:
# Name             0
# Age              0
# Gender           0
# Annual Income    0
# Education        0
# Phone Owned      0
# Email            0
# Web              0
# Mobile           0
# Walk-in          0
# Video Call       0
# Phone Call       0
# Letter           0
# dtype: int64
